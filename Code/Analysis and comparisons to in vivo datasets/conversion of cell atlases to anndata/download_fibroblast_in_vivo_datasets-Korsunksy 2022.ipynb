# %% [markdown]
# # Download Cross-tissue Atlas 2022 (MED)

# %%
install.packages("httr")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(httr)

# Define the list of URLs
urls <- c(
  "https://singlecell.broadinstitute.org/single_cell/data/public/SCP738/cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs.mtx",
  "https://singlecell.broadinstitute.org/single_cell/data/public/SCP738/cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs_barcodes.tsv",
  "https://singlecell.broadinstitute.org/single_cell/data/public/SCP738/cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs_genes.tsv",
  "https://singlecell.broadinstitute.org/single_cell/data/public/SCP738/cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=metaData.txt",
  "https://singlecell.broadinstitute.org/single_cell/studies/5e442d10771a5b0edfae4a75/manifest"
)
# Define your target directory
target_dir <- "/data/norman/southark/external_datasets/fibroblast_atlas_med_2022"  # replace with your desired directory

# Ensure the target directory exists
if (!dir.exists(target_dir)) {
  dir.create(target_dir, recursive = TRUE)
}

# Define the path for the downloaded file
file_path <- file.path(target_dir, "exprs.mtx")

# Download the file
response <- GET(url, write_disk(file_path, overwrite = TRUE), config = config(ssl_verifypeer = FALSE))

# Check the status of the download
if (status_code(response) == 200) {
  message("File successfully downloaded to ", file_path)
} else {
  message("Failed to download file. Status: ", status_code(response))
}
# Out:
# File successfully downloaded: cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs.mtx
#
# File successfully downloaded: cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs_barcodes.tsv
#
# File successfully downloaded: cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=exprs_genes.tsv
#
# File successfully downloaded: cross-tissue-single-cell-stromal-atlas-identifies-shared-pathological-fibroblast-phenotypes-in-four-chronic-inflammatory-diseases?filename=metaData.txt
#
# File successfully downloaded: manifest

# %% [markdown]
# ### Switch to python environment

# %%
import scanpy as sc
import pandas as pd
import scipy.io
import numpy as np


data_dir = "/data/norman/southark/external_datasets/fibroblast_atlas_med_2022/"

# Load the expression matrix
expression_matrix = scipy.io.mmread(data_dir+"exprs.mtx").T.tocsr()

# Load the barcodes
barcodes = pd.read_csv(data_dir+"exprs_barcodes.tsv", header=None, sep="\t")
barcodes = barcodes[0].values

# Load the genes
genes = pd.read_csv(data_dir+"exprs_genes.tsv", header=None, sep="\t")
genes = genes[0].values

# Load the metadata
metadata = pd.read_csv(data_dir+"metaData.txt", sep="\t", index_col=0)

# Verify that the barcodes in the metadata match the barcodes in the expression matrix
metadata = metadata.loc[barcodes]

# Create an AnnData object
adata = sc.AnnData(X=expression_matrix, obs=metadata, var=pd.DataFrame(index=genes))

# Verify the AnnData object
adata
# Out:
# /tmp/ipykernel_329427/97636735.py:21: DtypeWarning: Columns (12,13,14,15,16,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(data_dir+"metaData.txt", sep="\t", index_col=0)
# AnnData object with n_obs × n_vars = 102441 × 19952
#     obs: 'species', 'species__ontology_label', 'disease', 'disease__ontology_label', 'organ', 'organ__ontology_label', 'library_preparation_protocol', 'library_preparation_protocol__ontology_label', 'sex', 'biosample_id', 'donor_id', 'gut_inflam_pathology', 'inflam_score', 'nUMI', 'nGene', 'percent_mito', 'sample_type', 'cell_type_within_tissue', 'cell_type_integrated', 'experimental_condition'

# %%
# Identify columns with mixed types
def find_mixed_type_columns(df):
    mixed_columns = []
    for col in df.columns:
        if df[col].apply(type).nunique() > 1:
            mixed_columns.append(col)
    return mixed_columns

mixed_columns = find_mixed_type_columns(metadata)
print("Columns with mixed types:", mixed_columns)

# %% [markdown]
# Columns with mixed types: ['gut_inflam_pathology', 'inflam_score', 'nUMI', 'nGene', 'percent_mito', 'cell_type_within_tissue', 'cell_type_integrated']

# %%
adata.obs.igut_inflam_pathology = adata.obs.gut_inflam_pathology.astype('category')
adata.obs.inflam_score = adata.obs.inflam_score.astype('float')
adata.obs.nUMI = adata.obs.nUMI.astype('int')
adata.obs.nGene = adata.obs.nGene.astype('int')
adata.obs.percent_mito = adata.obs.percent_mito.astype('float')
adata.obs.cell_type_within_tissue = adata.obs.cell_type_within_tissue.astype('category')
adata.obs.cell_type_integrated = adata.obs.cell_type_integrated.astype('category')

# %%
adata.obs
# Out:
#                                         species species__ontology_label  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3  NCBITaxon:9606            Homo sapiens
# AAACGCTTCCTTATAC_SalivaryGland3  NCBITaxon:9606            Homo sapiens
# AAAGGATTCTGCATGA_SalivaryGland3  NCBITaxon:9606            Homo sapiens
# AAAGGATTCTTTCCAA_SalivaryGland3  NCBITaxon:9606            Homo sapiens
# AAAGGGCAGAGTGTTA_SalivaryGland3  NCBITaxon:9606            Homo sapiens
# ...                                         ...                     ...
# TTTGTTGCAGGCACTC_Lung_C_Control  NCBITaxon:9606            Homo sapiens
# TTTGTTGCAGTGACCC_Lung_A_Tcells   NCBITaxon:9606            Homo sapiens
# TTTGTTGCATGGCTAT_Lung_B_ECs      NCBITaxon:9606            Homo sapiens
# TTTGTTGGTCAGGTAG_Lung_A_ECs      NCBITaxon:9606            Homo sapiens
# TTTGTTGGTCCATAGT_Lung_B_Tcells   NCBITaxon:9606            Homo sapiens
#
#                                        disease    disease__ontology_label  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3  MONDO:0006733           dry eye syndrome
# AAACGCTTCCTTATAC_SalivaryGland3  MONDO:0006733           dry eye syndrome
# AAAGGATTCTGCATGA_SalivaryGland3  MONDO:0006733           dry eye syndrome
# AAAGGATTCTTTCCAA_SalivaryGland3  MONDO:0006733           dry eye syndrome
# AAAGGGCAGAGTGTTA_SalivaryGland3  MONDO:0006733           dry eye syndrome
# ...                                        ...                        ...
# TTTGTTGCAGGCACTC_Lung_C_Control  MONDO:0015925  interstitial lung disease
# TTTGTTGCAGTGACCC_Lung_A_Tcells   MONDO:0015925  interstitial lung disease
# TTTGTTGCATGGCTAT_Lung_B_ECs      MONDO:0015925  interstitial lung disease
# TTTGTTGGTCAGGTAG_Lung_A_ECs      MONDO:0015925  interstitial lung disease
# TTTGTTGGTCCATAGT_Lung_B_Tcells   MONDO:0015925  interstitial lung disease
#
#                                           organ organ__ontology_label  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3  UBERON:0001830  minor salivary gland
# AAACGCTTCCTTATAC_SalivaryGland3  UBERON:0001830  minor salivary gland
# AAAGGATTCTGCATGA_SalivaryGland3  UBERON:0001830  minor salivary gland
# AAAGGATTCTTTCCAA_SalivaryGland3  UBERON:0001830  minor salivary gland
# AAAGGGCAGAGTGTTA_SalivaryGland3  UBERON:0001830  minor salivary gland
# ...                                         ...                   ...
# TTTGTTGCAGGCACTC_Lung_C_Control  UBERON:0002048                  lung
# TTTGTTGCAGTGACCC_Lung_A_Tcells   UBERON:0002048                  lung
# TTTGTTGCATGGCTAT_Lung_B_ECs      UBERON:0002048                  lung
# TTTGTTGGTCAGGTAG_Lung_A_ECs      UBERON:0002048                  lung
# TTTGTTGGTCCATAGT_Lung_B_Tcells   UBERON:0002048                  lung
#
#                                 library_preparation_protocol  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3                  EFO:0009922
# AAACGCTTCCTTATAC_SalivaryGland3                  EFO:0009922
# AAAGGATTCTGCATGA_SalivaryGland3                  EFO:0009922
# AAAGGATTCTTTCCAA_SalivaryGland3                  EFO:0009922
# AAAGGGCAGAGTGTTA_SalivaryGland3                  EFO:0009922
# ...                                                      ...
# TTTGTTGCAGGCACTC_Lung_C_Control                  EFO:0009922
# TTTGTTGCAGTGACCC_Lung_A_Tcells                   EFO:0009922
# TTTGTTGCATGGCTAT_Lung_B_ECs                      EFO:0009922
# TTTGTTGGTCAGGTAG_Lung_A_ECs                      EFO:0009922
# TTTGTTGGTCCATAGT_Lung_B_Tcells                   EFO:0009922
#
#                                 library_preparation_protocol__ontology_label  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3                                    10x 3' v3
# AAACGCTTCCTTATAC_SalivaryGland3                                    10x 3' v3
# AAAGGATTCTGCATGA_SalivaryGland3                                    10x 3' v3
# AAAGGATTCTTTCCAA_SalivaryGland3                                    10x 3' v3
# AAAGGGCAGAGTGTTA_SalivaryGland3                                    10x 3' v3
# ...                                                                      ...
# TTTGTTGCAGGCACTC_Lung_C_Control                                    10x 3' v3
# TTTGTTGCAGTGACCC_Lung_A_Tcells                                     10x 3' v3
# TTTGTTGCATGGCTAT_Lung_B_ECs                                        10x 3' v3
# TTTGTTGGTCAGGTAG_Lung_A_ECs                                        10x 3' v3
# TTTGTTGGTCCATAGT_Lung_B_Tcells                                     10x 3' v3
#
#                                      sex    biosample_id        donor_id  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3   female  SalivaryGland3  SalivaryGland3
# AAACGCTTCCTTATAC_SalivaryGland3   female  SalivaryGland3  SalivaryGland3
# AAAGGATTCTGCATGA_SalivaryGland3   female  SalivaryGland3  SalivaryGland3
# AAAGGATTCTTTCCAA_SalivaryGland3   female  SalivaryGland3  SalivaryGland3
# AAAGGGCAGAGTGTTA_SalivaryGland3   female  SalivaryGland3  SalivaryGland3
# ...                                  ...             ...             ...
# TTTGTTGCAGGCACTC_Lung_C_Control  unknown  Lung_C_Control          Lung_C
# TTTGTTGCAGTGACCC_Lung_A_Tcells   unknown   Lung_A_Tcells          Lung_A
# TTTGTTGCATGGCTAT_Lung_B_ECs      unknown      Lung_B_ECs          Lung_B
# TTTGTTGGTCAGGTAG_Lung_A_ECs      unknown      Lung_A_ECs          Lung_A
# TTTGTTGGTCCATAGT_Lung_B_Tcells   unknown   Lung_B_Tcells          Lung_B
#
#                                 gut_inflam_pathology  inflam_score   nUMI  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3                  NaN      0.381334   6313
# AAACGCTTCCTTATAC_SalivaryGland3                  NaN      0.381334  11020
# AAAGGATTCTGCATGA_SalivaryGland3                  NaN      0.381334   5787
# AAAGGATTCTTTCCAA_SalivaryGland3                  NaN      0.381334   5306
# AAAGGGCAGAGTGTTA_SalivaryGland3                  NaN      0.381334   7568
# ...                                              ...           ...    ...
# TTTGTTGCAGGCACTC_Lung_C_Control                  NaN           NaN   8630
# TTTGTTGCAGTGACCC_Lung_A_Tcells                   NaN           NaN  10177
# TTTGTTGCATGGCTAT_Lung_B_ECs                      NaN           NaN   8504
# TTTGTTGGTCAGGTAG_Lung_A_ECs                      NaN           NaN  24209
# TTTGTTGGTCCATAGT_Lung_B_Tcells                   NaN           NaN   3500
#
#                                  nGene  percent_mito sample_type  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3   2335      0.089656     primary
# AAACGCTTCCTTATAC_SalivaryGland3   3113      0.093013     primary
# AAAGGATTCTGCATGA_SalivaryGland3   2367      0.140142     primary
# AAAGGATTCTTTCCAA_SalivaryGland3   1992      0.174331     primary
# AAAGGGCAGAGTGTTA_SalivaryGland3   2417      0.074789     primary
# ...                                ...           ...         ...
# TTTGTTGCAGGCACTC_Lung_C_Control   3025      0.066280    cultured
# TTTGTTGCAGTGACCC_Lung_A_Tcells    3289      0.084504    cultured
# TTTGTTGCATGGCTAT_Lung_B_ECs       1541      0.107008    cultured
# TTTGTTGGTCAGGTAG_Lung_A_ECs       5026      0.081581    cultured
# TTTGTTGGTCCATAGT_Lung_B_Tcells    1689      0.119143    cultured
#
#                                 cell_type_within_tissue cell_type_integrated  \
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3                    CD34            FBLN1+ C5
# AAACGCTTCCTTATAC_SalivaryGland3                   CCL19                   C2
# AAAGGATTCTGCATGA_SalivaryGland3                    CD34     SPARC+COL3A1+ C4
# AAAGGATTCTTTCCAA_SalivaryGland3                    CD34                   C1
# AAAGGGCAGAGTGTTA_SalivaryGland3                    CD34            FBLN1+ C5
# ...                                                 ...                  ...
# TTTGTTGCAGGCACTC_Lung_C_Control                     NaN                  NaN
# TTTGTTGCAGTGACCC_Lung_A_Tcells                      NaN                  NaN
# TTTGTTGCATGGCTAT_Lung_B_ECs                         NaN                  NaN
# TTTGTTGGTCAGGTAG_Lung_A_ECs                         NaN                  NaN
# TTTGTTGGTCCATAGT_Lung_B_Tcells                      NaN                  NaN
#
#                                 experimental_condition
# NAME
# AAACGCTCAGTTGTCA_SalivaryGland3                primary
# AAACGCTTCCTTATAC_SalivaryGland3                primary
# AAAGGATTCTGCATGA_SalivaryGland3                primary
# AAAGGATTCTTTCCAA_SalivaryGland3                primary
# AAAGGGCAGAGTGTTA_SalivaryGland3                primary
# ...                                                ...
# TTTGTTGCAGGCACTC_Lung_C_Control                Control
# TTTGTTGCAGTGACCC_Lung_A_Tcells                  Tcells
# TTTGTTGCATGGCTAT_Lung_B_ECs                        ECs
# TTTGTTGGTCAGGTAG_Lung_A_ECs                        ECs
# TTTGTTGGTCCATAGT_Lung_B_Tcells                  Tcells
#
# [102441 rows x 20 columns]

# %%
# Save the AnnData object to disk
adata.write("/data/norman/southark/external_datasets/fibroblast_atlas_med_2022/med_2022_normalized_expr.h5ad")

# %%
# Load the AnnData object from disk
loaded_adata = sc.read("/data/norman/southark/external_datasets/fibroblast_atlas_med_2022/med_2022_normalized_expr.h5ad")

# Verify the loaded object
loaded_adata
# Out:
# AnnData object with n_obs × n_vars = 102441 × 19952
#     obs: 'species', 'species__ontology_label', 'disease', 'disease__ontology_label', 'organ', 'organ__ontology_label', 'library_preparation_protocol', 'library_preparation_protocol__ontology_label', 'sex', 'biosample_id', 'donor_id', 'gut_inflam_pathology', 'inflam_score', 'nUMI', 'nGene', 'percent_mito', 'sample_type', 'cell_type_within_tissue', 'cell_type_integrated', 'experimental_condition'
